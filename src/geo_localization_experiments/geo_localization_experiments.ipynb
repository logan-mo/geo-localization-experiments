# %%
# !git clone https://github.com/logan-mo/geo-localization-experiments.git
# Out:
# Cloning into 'geo-localization-experiments'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 29 (delta 6), reused 26 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (29/29), 170.80 KiB | 8.54 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
# !pip install /content/geo-localization-experiments/
# Out:
# Processing ./geo-localization-experiments
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 33.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.8/252.8 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 84.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 41.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 87.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 72.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 7.0 MB/s eta 0:00:00
# ...

# %%
# upload images.zip and telemetry.csv

# %%
# !apt install unzip
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# unzip is already the newest version (6.0-26ubuntu3.2).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %%
# !cd /content/geo-localization-experiments/src/data && unzip images.zip
# Out:
# Archive:  images.zip
#    creating: images/
#   inflating: images/20260310_173657_991.png
#   inflating: images/20260310_173659_031.png
#   inflating: images/20260310_173700_067.png
#   inflating: images/20260310_173701_068.png
#   inflating: images/20260310_173702_104.png
#   inflating: images/20260310_173703_104.png
#   inflating: images/20260310_173704_144.png
#   inflating: images/20260310_173705_180.png
#   inflating: images/20260310_173706_180.png
#   inflating: images/20260310_173707_220.png
#   inflating: images/20260310_173708_256.png
#   inflating: images/20260310_173709_256.png
#   inflating: images/20260310_173710_292.png
#   inflating: images/20260310_173711_332.png
#   inflating: images/20260310_173712_372.png
#   inflating: images/20260310_173713_412.png
#   inflating: images/20260310_173714_414.png
#   inflating: images/20260310_173715_415.png
#   inflating: images/20260310_173716_450.png
#   inflating: images/20260310_173717_489.png
# ...

# %%
# !rm -rf  /content/geo-localization-experiments/src/data/images.zip

# %%
# !cd /content/geo-localization-experiments/src/geo_localization_experiments && python step1_preprocessing.py --images_dir /content/geo-localization-experiments/src/data/images --csv_path /content/geo-localization-experiments/src/data/telemetry.csv --reference_image 20260310_173956_994.png --output_dir /content/geo-localization-experiments/src/data/output_dir
# Out:
# [CSV] Loaded 229 rows from /content/geo-localization-experiments/src/data/telemetry.csv
# [REF] 20260310_173956_994.png  alt=619.9m  lat=33.551182  lon=73.124471
# [CAM] Source=default  focal=4.5mm  FOV=70.8°×56.1°
# [REF FP] 881.6m × 661.2m  GSD=1.377m/px
# Building pairs: 100% 228/228 [00:26<00:00,  8.71it/s]
#
# [DONE] Built 228 pairs → /content/geo-localization-experiments/src/data/output_dir
#        Index saved to /content/geo-localization-experiments/src/data/output_dir/pairs_index.csv
#        GT distance range: 0.0m – 26.6m
#        Inscribed crop retention: 50.9% avg  (min 49.5%)
#        Query valid-pixel ratio: 81.8% avg after masking
#
# Pairs summary:
#                   query  gt_dist_m  scale_factor  query_alt_m
# 20260310_173657_991.png   0.071283      0.695512       431.12
# 20260310_173659_031.png   0.071283      0.695512       431.12
# 20260310_173700_067.png   0.071283      0.695512       431.12
# 20260310_173701_068.png   0.071283      0.695512       431.12
# ...

# %%
# !cd /content/geo-localization-experiments/src/geo_localization_experiments && python step2_smoke_test.py --pairs_dir /content/geo-localization-experiments/src/data/output_dir --output_dir /content/geo-localization-experiments/src/data/evaluation_out
# Out:
# [SMOKE] Found 228 pairs in index.
#
# ...
#   Synthetic_Good  (228 pairs, 0 failures / 0.0%)
# ...
#   MAE      : 3.76 m
#   RMSE     : 4.79 m
#   Median   : 3.23 m
#   P75 / P90: 5.55 m  /  8.15 m
#   ── Accuracy ──────────────────────────────────
#   @  1m:  22.4%  ███████████░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░
#   @  5m:  68.9%  ██████████████████████████████████░░░░░░░░░░░░░░░░
#   @ 10m:  96.0%  ████████████████████████████████████████████████░░
#   @ 25m: 100.0%  ██████████████████████████████████████████████████
#   @ 50m: 100.0%  ██████████████████████████████████████████████████
#   @100m: 100.0%  ██████████████████████████████████████████████████
#   ── Timing ────────────────────────────────────
#   Mean inference: 139.0 ms  P95: 193.9 ms
# ...
#
# ...
#   Synthetic_Weak  (228 pairs, 45 failures / 19.7%)
# ...
#   MAE      : 16.12 m
#   RMSE     : 20.48 m
#   Median   : 13.48 m
#   P75 / P90: 23.62 m  /  33.82 m
#   ── Accuracy ──────────────────────────────────
# ...

# %%
# !cd /content/geo-localization-experiments/src/geo_localization_experiments && python step3_roma_baseline.py --pairs_dir /content/geo-localization-experiments/src/data/output_dir --output_dir /content/geo-localization-experiments/src/data/evaluation_out --num_samples 2000 --visualise
# Out:
# [RoMa] Processing 228 pairs on CUDA
# [RoMa] local_correlation patched in matcher (CUDA 12.8 coarse-only mode)
# [RoMa] Loading model on cuda ...
# 2026-03-11 07:04:40.890 | INFO     | romatch.models.model_zoo.roma_models:roma_model:255 - Using coarse resolution (560, 560), and upsample res (864, 864)
# [RoMa] Model ready in 9.1s
# RoMa: 100% 228/228 [13:30<00:00,  3.56s/it]
#
# [RoMa] Raw predictions saved → /content/geo-localization-experiments/src/data/evaluation_out/preds_roma.csv
#
# ...
#   RoMa  (228 pairs, 0 failures / 0.0%)
# ...
#   MAE      : 79.76 m
#   RMSE     : 117.67 m
#   Median   : 65.34 m
#   P75 / P90: 83.00 m  /  154.42 m
#   ── Accuracy ──────────────────────────────────
#   @  1m:   0.0%  ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░
#   @  5m:   0.4%  ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░
#   @ 10m:   1.3%  ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░
#   @ 25m:   5.3%  ██░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░
# ...

# %%
# !pip uninstall romatch -y
# Out:
# Found existing installation: romatch 0.1.2
# Uninstalling romatch-0.1.2:
#   Successfully uninstalled romatch-0.1.2

# %%
# !pip install git+https://github.com/Parskatt/RoMa.git
# Out:
# ...
#   Cloning https://github.com/Parskatt/RoMa.git to /tmp/pip-req-build-fvzs_fz_
#   Running command git clone --filter=blob:none --quiet https://github.com/Parskatt/RoMa.git /tmp/pip-req-build-fvzs_fz_
#   Resolved https://github.com/Parskatt/RoMa.git to commit 77f8d68803526dcddfd9b7a46bc76125bdc25f15
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for romatch: filename=romatch-0.1.2-py3-none-any.whl size=67226 sha256=919116c331a12c98ddb2438c1cc31892d9fd2d6eeb66dd0a1ec6ac6c4a652f3e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-j_eulmhv/wheels/a8/cc/da/92741ac9765983af5c18acbb1ffe3d916ff043744a96a0591d
# Successfully built romatch
# ...

# %%
# !rm -rf /content/geo-localization-experiments/src/data/evaluation_out/

# %%
# !zip -r /content/evaluation_out.zip /content/geo-localization-experiments/src/data/evaluation_out
# Out:
#   adding: content/geo-localization-experiments/src/data/evaluation_out/ (stored 0%)
#   adding: content/geo-localization-experiments/src/data/evaluation_out/scatter_per_pair.png (deflated 9%)
#   adding: content/geo-localization-experiments/src/data/evaluation_out/comparison_table.csv (deflated 32%)
#   adding: content/geo-localization-experiments/src/data/evaluation_out/viz_roma/ (stored 0%)
#   adding: content/geo-localization-experiments/src/data/evaluation_out/viz_roma/20260310_174044_421.png (deflated 0%)
#   adding: content/geo-localization-experiments/src/data/evaluation_out/viz_roma/20260310_174001_106.png (deflated 0%)
#   adding: content/geo-localization-experiments/src/data/evaluation_out/viz_roma/20260310_173924_073.png (deflated 0%)
#   adding: content/geo-localization-experiments/src/data/evaluation_out/viz_roma/20260310_173751_495.png (deflated 0%)
#   adding: content/geo-localization-experiments/src/data/evaluation_out/viz_roma/20260310_174028_001.png (deflated 0%)
# ...

# %%
import torch
print(torch.version.cuda)        # e.g. 12.1
# !nvcc --version
# Out:
# 12.8
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2025 NVIDIA Corporation
# Built on Fri_Feb_21_20:23:50_PST_2025
# Cuda compilation tools, release 12.8, V12.8.93
# Build cuda_12.8.r12.8/compiler.35583870_0
